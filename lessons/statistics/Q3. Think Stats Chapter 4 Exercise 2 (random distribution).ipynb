# %% [markdown]
# ## Exercise 2
# The numbers generated by random.random are supposed to be uniform between 0 and 1; that is, every value in the range should have the same probability.

# %% [markdown]
# Generate 1000 numbers from random.random and plot their PMF and CDF. Is the distribution uniform?

# %%
import numpy as np
import os

os.chdir('../../ThinkStats2/code')
import thinkstats2
import thinkplot

# %%
nums = np.random.random(1000)
nums[:10]
# Out:
# array([0.35490748, 0.23560738, 0.41897198, 0.5684907 , 0.62594531,
#        0.24709504, 0.0886374 , 0.93151124, 0.87029059, 0.71507647])

# %%
pmf = thinkstats2.Pmf(nums)
thinkplot.Pmf(pmf, linewidth=0.1)
thinkplot.Config(xlabel='Random variate', ylabel='PMF')

# %%
cdf = thinkstats2.Cdf(nums)
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='Random variate', ylabel='CDF')

# %%
nums = np.random.uniform(0, 1, 1000)
nums[:10]
# Out:
# array([0.82077086, 0.88396985, 0.4915982 , 0.38285119, 0.50587233,
#        0.31322804, 0.93959661, 0.59724085, 0.35927434, 0.41477152])
